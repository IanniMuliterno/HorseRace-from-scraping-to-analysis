# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
url = 'https://www.racing.com/trainers/'
driver.get(url)

# %%
print(BeautifulSoup(driver.page_source, 'html.parser'))
# Out:
# <html lang="en"><head><script async="" src="https://www.clarity.ms/s/0.7.20/clarity.js"></script><script async="" src="https://www.clarity.ms/tag/kp9uulpfgi?ref=gtm2"></script><script async="" src="https://connect.facebook.net/signals/config/1631310827106969?v=2.9.142&amp;r=stable&amp;domain=www.racing.com&amp;hme=e82209ddce2f5ef9f00773b102465283e977acad712d554991b839c35823b905&amp;ex_m=62%2C103%2C91%2C95%2C53%2C3%2C87%2C61%2C14%2C85%2C78%2C44%2C46%2C145%2C148%2C159%2C155%2C156%2C158%2C25%2C88%2C45%2C68%2C157%2C140%2C143%2C152%2C153%2C160%2C112%2C13%2C43%2C164%2C163%2C114%2C16%2C29%2C32%2C1%2C36%2C57%2C58%2C59%2C63%2C82%2C15%2C12%2C84%2C81%2C80%2C92%2C94%2C31%2C93%2C26%2C22%2C141%2C144%2C121%2C24%2C9%2C10%2C11%2C5%2C6%2C21%2C19%2C20%2C49%2C54%2C56%2C66%2C89%2C23%2C67%2C8%2C7%2C71%2C41%2C18%2C17%2C4%2C73%2C79%2C72%2C77%2C33%2C35%2C76%2C48%2C74%2C28%2C37%2C65%2C0%2C83%2C75%2C2%2C30%2C55%2C34%2C90%2C38%2C70%2C60%2C40%2C39%2C96%2C52%2C51%2C27%2C86%2C50%2C47%2C42%2C69%2C64%2C97"></script>
# ...

# %%
# You may need to wait for the page to load
#flex w-full pt-14 
#w-full pl-2
elements = driver.find_elements(By.CLASS_NAME, 'w-full pl-2') 
#trainers_names = [element.text for element in trainers_elements]
print(trainers_elements.text)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\IM_py\anaconda3\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\IM_py\anaconda3\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File c:\Users\IM_py\anaconda3\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
#
# ...

# %%
 from selenium.webdriver.common.by import By
 #driver.find_element(By.CLASS_NAME,'w-full pl-2')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [34], in <cell line: 2>()
#       1 from selenium.webdriver.common.by import By
# ----> 2 driver.find_element(By.CLASS_NAME,'w-full pl-2')
#
# File c:\Users\IM_py\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:976, in WebDriver.find_element(self, by, value)
#     974         by = By.CSS_SELECTOR
#     975         value = '[name="%s"]' % value
# --> 976 return self.execute(Command.FIND_ELEMENT, {
#     977     'using': by,
#     978     'value': value})['value']
#
# File c:\Users\IM_py\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
# ...

# %%
#for name in trainers_names:
#    print(name)

#driver.quit()
