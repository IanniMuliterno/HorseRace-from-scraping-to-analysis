# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
url = 'https://www.racing.com/trainers/'
driver.get(url)

# %%
print(driver.page_source, 'html.parser')
# Out:
# <html lang="en"><head><script async="" src="https://www.clarity.ms/s/0.7.20/clarity.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-D09593FEJ7&amp;l=dataLayer&amp;cx=c"></script><script async="" src="https://www.clarity.ms/tag/kp9uulpfgi?ref=gtm2"></script><script src="https://connect.facebook.net/signals/config/1631310827106969?v=2.9.143&amp;r=stable&amp;domain=www.racing.com&amp;hme=1e96626f56fb37feabdb16bd09d3dbece570479b2ec677eec7364c762eaf296e&amp;ex_m=62%2C104%2C92%2C96%2C53%2C3%2C88%2C61%2C14%2C86%2C79%2C44%2C46%2C146%2C149%2C160%2C156%2C157%2C159%2C25%2C89%2C45%2C68%2C158%2C141%2C144%2C153%2C154%2C161%2C113%2C13%2C43%2C165%2C164%2C115%2C16%2C29%2C32%2C1%2C36%2C57%2C58%2C59%2C63%2C83%2C15%2C12%2C85%2C82%2C81%2C93%2C95%2C31%2C94%2C26%2C22%2C142%2C145%2C122%2C24%2C9%2C10%2C11%2C5%2C6%2C21%2C19%2C20%2C49%2C54%2C56%2C66%2C90%2C23%2C67%2C8%2C7%2C71%2C41%2C18%2C17%2C4%2C73%2C80%2C72%2C78%2C40%2C39%2C77%2C33%2C35%2C76%2C48%2C74%2C28%2C37%2C65%2C0%2C84%2C75%2C2%2C30%2C55%2C34%2C91%2C38%2C70%2C60%2C97%2C52%2C51%2C27%2C87%2C50%2C47%2C42%2C69%2C64%2C98" async=""></script><script async="" src="//connect.facebook.net/en_US/fbevents.js"></script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NJJTCC&amp;gtm_auth=&amp;gtm_preview=&amp;gtm_cookies_win=x"></script><script>
#       (function(w,d,s,l,i){w[l]=w[l]||[];
#         w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js', });
#         var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
#         j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl+'&gtm_auth=&gtm_preview=&gtm_cookies_win=x';
#         f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-NJJTCC');</script>
#     <meta charset="UTF-8">
#     <link rel="icon" type="image/svg+xml" href="/profile/favicon.ico">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Trainers Premiership - RACING.COM</title>
#     <script type="module" crossorigin="" src="/profile/assets/index-a5ca5ae7.js"></script>
#     <link rel="stylesheet" href="/profile/assets/index-6c70d83e.css">
#   <style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-container__r5ivn {
#   /* 10px padding on mobile */
#   margin-left: auto;
#   margin-right: auto;
#   width: 100%;
#   padding-left: 1rem;
#   padding-right: 1rem;
#   /* 20px padding on tablet */
# }
#
# @media (min-width: 768px) {
#   .index_rdc-container__r5ivn {
#     padding-left: 2rem;
#     padding-right: 2rem;
#   }
# }
#
# .index_rdc-container__r5ivn {
#   /* 30px padding on desktop */
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-container__r5ivn {
#     max-width: 132.0rem;
#     padding-left: 3rem;
#     padding-right: 3rem;
#   }
# }
#
# .index_rdc-container--no-padding__V4s-Y {
#   padding-left: 0px;
#   padding-right: 0px;
# }
#
# @media (min-width: 768px) {
#   .index_rdc-container--no-padding__V4s-Y {
#     padding-left: 0px;
#     padding-right: 0px;
#   }
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-container--no-padding__V4s-Y {
#     padding-left: 0px;
#     padding-right: 0px;
#   }
# }
#
# .index_rdc-container--desktop-only__R5REe {
#   padding-left: 0px;
#   padding-right: 0px;
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-container--desktop-only__R5REe {
#     padding-left: 3rem;
#     padding-right: 3rem;
#   }
# }
# </style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-icon__3algj {
#   display: flex;
#   align-items: center;
#   justify-content: center;
#   width: 1em;
#   height: 1em;
# }
#
# .index_rdc-icon--inline__w3847 {
#   display: inline-flex;
# }
#
# .index_rdc-icon--button__UPEay {
#   border-radius: 9999px;
#   border-width: 1px;
#   border-color: inherit;
#   cursor: pointer;
# }
#
# .index_rdc-icon--button__UPEay i {
#     font-size: 0.5em;
#   }
#
# .index_rdc-icon--dark__Lbgw8 {
#   --tw-text-opacity: 1;
#   color: rgba(255, 255, 255, var(--tw-text-opacity));
# }
#
# .index_rdc-icon--dark__Lbgw8.index_rdc-icon--button__UPEay {
#     border-style: none;
#     --tw-bg-opacity: 1;
#     background-color: rgba(51, 51, 51, var(--tw-bg-opacity));
#   }
# </style><script>
#       window.dataLayer = window.dataLayer || [];
#       window.dataLayer.push({"application_name":"racing.com"})</script><style type="text/css">/*! racing-ui v1.0.0 */
# .index-module_rdc-modal__overlay__PtQaW {
#   top: 0px;
#   right: 0px;
#   bottom: 0px;
#   left: 0px;
#   --tw-bg-opacity: 1;
#   background-color: rgba(0, 0, 0, var(--tw-bg-opacity));
#   --tw-bg-opacity: 0.8;
#   position: fixed;
#   display: flex;
#   align-items: center;
#   justify-content: center;
#   z-index: 100000;
# }
#
# .index-module_rdc-modal--padding__DBRWH .index-module_rdc-modal__overlay__PtQaW {
#   padding: 1.5rem;
# }
#
# .index-module_rdc-modal__content__swG1M {
#   width: 100%;
#   position: relative;
# }
#
# .index-module_rdc-modal__content__swG1M:focus {
#   outline: 2px solid transparent;
#   outline-offset: 2px;
# }
#
# .index-module_rdc-modal__content--fixed-width__el3UA {
#   max-width: 132.0rem;
# }
#
# @media (min-width: 1024px) {
#   .index-module_rdc-modal__content--fixed-width__el3UA {
#     padding-left: 3rem;
#     padding-right: 3rem;
#   }
# }
#
# .index-module_rdc-modal__content--small__hWE4x {
#   max-width: 64rem;
# }
#
# .index-module_rdc-modal__content--full-height__KYUWi {
#   height: 100%;
# }</style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-section__jAGhe {
#   padding-top: 3rem;
#   padding-bottom: 3rem;
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-section__jAGhe {
#     padding-top: 5rem;
#     padding-bottom: 5rem;
#   }
# }
#
# .index_rdc-section--md-padding__7l-M- {
#   padding-top: 1.5rem;
#   padding-bottom: 1.5rem;
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-section--md-padding__7l-M- {
#     padding-top: 2rem;
#     padding-bottom: 2rem;
#   }
# }
#
# .index_rdc-section--sm-padding__h5OMS {
#   padding-top: 1rem;
#   padding-bottom: 1rem;
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-section--sm-padding__h5OMS {
#     padding-top: 1rem;
#     padding-bottom: 1rem;
#   }
# }
#
# .index_rdc-section--no-padding__IrZ3I {
#   padding-top: 0px;
#   padding-bottom: 0px;
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-section--no-padding__IrZ3I {
#     padding-top: 0px;
#     padding-bottom: 0px;
#   }
# }
#
# .index_rdc-section--alt__YxGpn {
#   --tw-bg-opacity: 1;
#   background-color: rgba(245, 245, 245, var(--tw-bg-opacity));
# }
# </style><script src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" async="" type="text/javascript"></script><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-tab-button__FkFF4 {
#   cursor: pointer;
#   font-family: Circular, Helvetica Neue, Helvetica, Arial, sans-serif;
#   font-weight: 700;
#   font-size: 1.6rem;
# }
#
# .index_rdc-tab-button--mini__MFUBx {
#   font-size: 1.4rem;
#   line-height: 1.8rem;
# }</style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-duration__NPx8D {
#   display: inline-flex;
#   width: auto;
#   align-items: stretch;
#   line-height: 1;
#   line-height: 1;
#   --tw-text-opacity: 1;
#   color: rgba(255, 255, 255, var(--tw-text-opacity));
# }
#
# .index_rdc-duration__icon__FEbR8 {
#   display: flex;
#   flex: 1 1 auto;
#   align-items: center;
#   justify-content: center;
#   --tw-bg-opacity: 1;
#   background-color: rgba(237, 28, 36, var(--tw-bg-opacity));
#   width: 1.6rem;
#   height: 1.6rem;
#   font-size: 1rem;
# }
#
# .index_rdc-duration--mini__eDyrJ .index_rdc-duration__icon__FEbR8 {
#     width: 1.4rem;
#     height: 1.4rem;
#     font-size: 0.8rem;
#   }
#
# .index_rdc-duration__time__YYsnF {
#   display: flex;
#   flex: 1 1 auto;
#   align-items: center;
#   --tw-bg-opacity: 1;
#   background-color: rgba(51, 51, 51, var(--tw-bg-opacity));
#   padding-left: 0.375rem;
#   padding-right: 0.375rem;
#   font-family: Circular, Helvetica Neue, Helvetica, Arial, sans-serif;
#   font-weight: 700;
#   font-size: 1.2rem;
# }
#
# .index_rdc-duration--mini__eDyrJ .index_rdc-duration__time__YYsnF {
#     padding-left: 0.25rem;
#     padding-right: 0.25rem;
#     font-size: 1rem;
#     font-size: 1.1rem;
#     min-width: 3.5rem;
#     justify-content: center;
#   }
# </style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-thumbnail__-jqD- {
#   width: 100%;
#   --tw-bg-opacity: 1;
#   background-color: rgba(222, 222, 222, var(--tw-bg-opacity));
#   background-size: cover;
#   transition-property: opacity;
#   transition-timing-function: cubic-bezier(0.4, 0, 0.2, 1);
#   transition-duration: 150ms;
#   position: relative;
# }
# .index_rdc-news-card__wTFHd:hover .index_rdc-thumbnail__-jqD- {
#     opacity: 0.8;
#   }
# .index_rdc-thumbnail__-jqD-::before {
#     content: '';
#     display: block;
#     /* ratio 16:9 */
#     padding-bottom: 56.25%;
#   }
#
# .index_rdc-thumbnail__rPlus__ZsNve > img{
#   z-index: 2;
#   position: absolute;
#   height: 50px;
#   width: 50px;
#   bottom: 30%;
#   left: 40%;
# }
#
# .index_rdc-thumbnail__rPlusMobile__rJglt > img{
#   z-index: 2;
#   position: absolute;
#   height: 20px;
#   bottom: 30%;
#   left: 40%;
# }
#
# .index_rdc-thumbnail__img__hsAKi {
#   top: 0px;
#   right: 0px;
#   bottom: 0px;
#   left: 0px;
#   display: block;
#   height: 100%;
#   width: 100%;
#   position: absolute;
#   object-fit: cover;
#   object-position: center;
# }
#
# .index_rdc-thumbnail__duration__Rkz8S {
#   top: 0px;
#   right: 0px;
#   display: flex;
#   position: absolute;
# }
#
# .index_rdc-thumbnail__duration--tr__Bba-3 {
#   /* default */
# }
#
# .index_rdc-thumbnail__duration--br__rIhDG {
#   top: auto;
#   right: 0px;
#   bottom: 0px;
# }
#
# .index_rdc-duration__zQLRU {
#   display: inline-flex;
#   width: auto;
#   align-items: stretch;
#   line-height: 1;
#   line-height: 1;
#   --tw-text-opacity: 1;
#   color: rgba(255, 255, 255, var(--tw-text-opacity));
# }
#
# .index_rdc-duration__icon__UCx0P {
#   display: flex;
#   flex: 1 1 auto;
#   align-items: center;
#   justify-content: center;
#   --tw-bg-opacity: 1;
#   background-color: rgba(237, 28, 36, var(--tw-bg-opacity));
#   width: 1.6rem;
#   height: 1.6rem;
#   font-size: 1rem;
# }
#
# .index_rdc-duration--mini__Pl--s .index_rdc-duration__icon__UCx0P {
#     width: 1.4rem;
#     height: 1.4rem;
#     font-size: 0.8rem;
#   }
#
# .index_rdc-duration__time__zy3wo {
#   display: flex;
#   flex: 1 1 auto;
#   align-items: center;
#   --tw-bg-opacity: 1;
#   background-color: rgba(51, 51, 51, var(--tw-bg-opacity));
#   padding-left: 0.375rem;
#   padding-right: 0.375rem;
#   font-family: Circular, Helvetica Neue, Helvetica, Arial, sans-serif;
#   font-weight: 700;
#   font-size: 1.2rem;
# }
#
# .index_rdc-duration--mini__Pl--s .index_rdc-duration__time__zy3wo {
#     padding-left: 0.25rem;
#     padding-right: 0.25rem;
#     font-size: 1rem;
#     font-size: 1.1rem;
#     min-width: 3.5rem;
#     justify-content: center;
#   }
#
# </style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-badge__-eFP6 {
#   display: inline-flex;
#   align-items: center;
#   border-radius: 0.25rem;
#   padding: 0px;
#   font-family: Roboto, Helvetica Neue, Helvetica, Arial, sans-serif;
#   font-weight: 700;
#   text-transform: uppercase;
#   font-style: normal;
#   line-height: 1;
#   --tw-text-opacity: 1;
#   color: rgba(255, 255, 255, var(--tw-text-opacity));
#   font-size: 0.9rem;
#   border: 1px solid;
#   border-color: #999999;
#   position: relative;
#   z-index: 3;
# }
# .index_rdc-badge__-eFP6 .index_rdc-badge--inner__4NhcR {
#     color: white;
#   }
#
# .index_rdc-spacer__1Lt-c {
#   display: inline-block;
#   width: 0.25rem;
# }
#
# .index_rdc-badge--primary__gI3rI {
#   --tw-bg-opacity: 1;
#   background-color: rgba(237, 28, 36, var(--tw-bg-opacity));
#   border: 1px solid;
#   border-color: #999999;
# }
#
# .index_rdc-badge-container__IzkKU {
#   padding: 0.3rem 0.4rem 0.3rem;
# }
#
# .index_rdc-badge-container__IzkKU span {
#     padding: 0;
#   }
#
# .index_rdc-badge--link__inverse__-xYGN .index_rdc-badge-container__IzkKU {
#     color: white;
#   }
#
# .index_rdc-badge--link__inverse__-xYGN:hover .index_rdc-badge-container__IzkKU {
#     color: inherit;
#   }
#
# .index_rdc-badge--link__lGjFt {
#   cursor: pointer;
#   border-width: 1px;
#   border-style: solid;
#   transition: all 250ms;
#   pointer-events: all;
# }
#
# .index_rdc-badge--link__lGjFt:hover {
#     opacity: 0.65;
#   }
#
# .index_rdc-badge--link__lGjFt .index_rdc-badge--inner__4NhcR {
#     color: white;
#     font-weight: 700;
#     display: inline-flex;
#   }
#
# .index_rdc-badge--link__lGjFt .index_rdc-badge--inner__4NhcR .index_rdc-icon-external-link__gH4MW {
#       margin-left: 5px;
#     }
#
# .index_rdc-badge--link__inverse__-xYGN {
#   --tw-bg-opacity: 1;
#   background-color: rgba(153, 153, 153, var(--tw-bg-opacity));
#   cursor: pointer;
#   border-width: 1px;
#   border-style: solid;
#   transition: all 250ms;
#   pointer-events: all;
# }
#
# .index_rdc-badge--link__inverse__-xYGN:hover {
#     background-color: transparent !important;
#   }
#
# .index_rdc-badge--link__inverse__-xYGN:hover .index_rdc-badge--inner__4NhcR {
#       color: inherit ;
#     }
#
# .index_rdc-badge--link__inverse__-xYGN .index_rdc-badge--inner__4NhcR {
#     z-index: 2;
#     color: inherit;
#     display: inline-flex;
#   }
#
# .index_rdc-badge--link__inverse__-xYGN .index_rdc-badge--inner__4NhcR .index_rdc-icon-external-link__gH4MW {
#       margin-left: 5px;
#     }
#
# .index_rdc-badge__icon__wolmi {
#   font-size: 0.8rem;
# }
#
# .index_rdc-badge__label__qaKgj {
# }
# </style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-news-card__baleq {
#   position: relative;
#   display: flex;
#   cursor: pointer;
#   flex-direction: column;
#   align-items: stretch;
#   height: 100%;
#   width: 100%;
#   --tw-bg-opacity: 1;
#   background-color: rgba(255, 255, 255, var(--tw-bg-opacity));
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-news-card__baleq:hover {
#     --tw-shadow: 0 4px 6px -1px rgba(0, 0, 0, 0.1), 0 2px 4px -1px rgba(0, 0, 0, 0.06);
#     box-shadow: var(--tw-ring-offset-shadow, 0 0 #0000), var(--tw-ring-shadow, 0 0 #0000), var(--tw-shadow);
#   }
# }
#
# .index_rdc-news-card__baleq {
#   transition-property: box-shadow;
#   transition-timing-function: cubic-bezier(0.4, 0, 0.2, 1);
#   transition-duration: 150ms;
#   transition-duration: 200ms;
#   transition-timing-function: cubic-bezier(0, 0, 0.2, 1);
# }
#
# .index_rdc-news-card--hero__5hD-E, .index_rdc-news-card--featured__PhB5k, .index_rdc-news-card--mini__m14Un {
#   background-color: transparent;
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-news-card--hero__5hD-E, .index_rdc-news-card--featured__PhB5k, .index_rdc-news-card--mini__m14Un {
#     --tw-bg-opacity: 1;
#     background-color: rgba(255, 255, 255, var(--tw-bg-opacity));
#   }
# }
#
# .index_rdc-news-card--mini__m14Un {
#   flex-direction: row;
#   align-items: flex-start
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-news-card--mini__m14Un:hover {
#     --tw-shadow: 0 0 #0000;
#     box-shadow: var(--tw-ring-offset-shadow, 0 0 #0000), var(--tw-ring-shadow, 0 0 #0000), var(--tw-shadow);
#   }
# }
#
# .index_rdc-news-card--mini__m14Un .index_rdc-news-card__link__kYr76 {
#     line-height: 1.3rem;
#     font-weight: 400;
#     font-size: 1.1rem ;
#   }
#
# .index_rdc-news-card--mini__m14Un .index_rdc-news-card__detail__ErB1W {
#     border: none;
#     display: flex;
#     justify-content: space-between;
#     align-self: stretch;
#   }
#
# .index_rdc-news-card--inline__bef0i {
#   float: right;
#   width: 32%;
# }
#
# @media (min-width: 1024px) {
#
# .index_rdc-news-card--inline__bef0i {
#     margin-left: 1.7em
# }
#   }
#
# .index_rdc-news-card--inline__bef0i .index_rdc-news-card--featured__PhB5k .index_rdc-news-card__title__Ypfs- {
#       font-weight: 700;
#       font-size: 1.4rem ;
#     }
#
# .index_rdc-news-card__detail__ErB1W {
#   border: 1px solid #DEDEDE;
# }
#
# .index_rdc-news-list__heading__mrWTO {
#   font-family: Circular, Helvetica Neue, Helvetica, Arial, sans-serif;
#   font-weight: 900;
#   --tw-text-opacity: 1;
#   color: rgba(51, 51, 51, var(--tw-text-opacity));
#   border-bottom-width: 2px;
#   font-size: 1.4rem;
#   line-height: 1.4;
#   padding: 0 1.2rem 0.8rem;
# }
#
# .index_rdc-news-list__heading--inline__ui66g {
#   --tw-bg-opacity: 1;
#   padding: 0.5625em 1rem;
#   border-color: black;
#   display: flex;
#   align-items: center;
#   justify-content: space-between;
#   font-family: Circular, Helvetica Neue, Helvetica, Arial, sans-serif;
#   line-height: 1;
#   --tw-text-opacity: 1;
#   font-size: 1.4rem;
#   letter-spacing: -0.02px;
#   margin-bottom: 	0.75rem;
# }
#
# .index_rdc-news-card__thumbnail__ohe0t {
#   flex: 0 0 auto;
#   transition-property: opacity;
#   transition-timing-function: cubic-bezier(0.4, 0, 0.2, 1);
#   transition-duration: 150ms;
# }
#
# .index_rdc-news-card__baleq:hover .index_rdc-news-card__thumbnail__ohe0t {
#     opacity: 0.8;
#   }
#
# .index_rdc-news-card--placeholder__td7m5 .index_rdc-news-card__thumbnail__ohe0t::before {
#     display: block;
#     --tw-bg-opacity: 1;
#     background-color: rgba(222, 222, 222, var(--tw-bg-opacity));
#     content: '';
#     padding-bottom: 56.25%;
#   }
#
# .index_rdc-news-card--mini__m14Un .index_rdc-news-card__thumbnail__ohe0t {
#     margin-right: 1rem;
#     width: 12rem;
#   }
#
# .index_rdc-news-card__detail__ErB1W {
#   display: flex;
#   flex-grow: 1;
#   flex-direction: column;
#   padding: 1.25rem;
# }
#
# .index_rdc-news-card--bordered__Iq5fk .index_rdc-news-card__detail__ErB1W {
#     border: 1px solid #DEDEDE
#   }
#
# .index_rdc-news-card--mini__m14Un .index_rdc-news-card__detail__ErB1W {
#     padding: 0px;
#     font-weight: 400;
#   }
#
# .index_rdc-news-card--placeholder__td7m5 .index_rdc-news-card__detail__ErB1W {
#     --tw-bg-opacity: 1;
#     background-color: rgba(245, 245, 245, var(--tw-bg-opacity));
#   }
#
# .index_rdc-news-card__link__kYr76 {
#   z-index: 1;
# }
#
# .index_rdc-news-card__link__kYr76:after {
#     content: '';
#     left: 0;
#     top: 0;
#     width: 100%;
#     height: 100%;
#     position: absolute;
#     display: block;
#     cursor: pointer;
#   }
#
# .index_rdc-news-card__title__Ypfs- {
#   font-family: Circular, Helvetica Neue, Helvetica, Arial, sans-serif;
#   font-weight: 700;
#   --tw-text-opacity: 1;
#   color: rgba(51, 51, 51, var(--tw-text-opacity));
#   transition-property: background-color, border-color, color, fill, stroke;
#   transition-timing-function: cubic-bezier(0.4, 0, 0.2, 1);
#   transition-duration: 150ms;
#   transition-duration: 300ms;
#   transition-timing-function: cubic-bezier(0, 0, 0.2, 1);
#   flex: 0 0 auto;
#   margin-bottom: 0.8rem;
#   font-size: 1.4rem;
#   line-height: 1.2;
# }
#
# @media (min-width: 1024px) {
#
# .index_rdc-news-card__title__Ypfs- {
#     height: 2.4em;
#
#     margin-bottom: 1.2rem
# }
#   }
#
# .index_rdc-news-card--featured__PhB5k .index_rdc-news-card__title__Ypfs- {
#     height: auto;
#   }
#
# @media (min-width: 1024px) {
#
# .index_rdc-news-card--featured__PhB5k .index_rdc-news-card__title__Ypfs- {
#       font-size: 2rem
#   }
#     }
#
# @media (min-width: 1024px) {
#
# .index_rdc-news-card--hero__5hD-E .index_rdc-news-card__title__Ypfs- {
#       font-size: 3rem
#   }
#     }
#
# .index_rdc-news-card--mini__m14Un .index_rdc-news-card__title__Ypfs- {
#     font-weight: 400;
#     font-size: 1.1rem;
#   }
#
# .index_rdc-news-card__baleq:hover .index_rdc-news-card__title__Ypfs- {
#     --tw-text-opacity: 1;
#     color: rgba(237, 28, 36, var(--tw-text-opacity));
#   }
#
# .index_rdc-news-card__description__v-RnZ {
#   flex-grow: 1;
#   font-weight: 400;
#   --tw-text-opacity: 1;
#   color: rgba(51, 51, 51, var(--tw-text-opacity));
#   font-size: 1.1rem;
#   line-height: 1.4;
#   margin-bottom: 1.2rem;
# }
#
# @media (min-width: 1024px) {
#
# .index_rdc-news-card__description__v-RnZ {
#     font-size: 1.4rem
# }
#   }
#
# .index_rdc-news-card__meta__TNbSg {
#   pointer-events: none;
#   font-family: Roboto, Helvetica Neue, Helvetica, Arial, sans-serif;
#   font-weight: 400;
#   --tw-text-opacity: 1;
#   color: rgba(153, 153, 153, var(--tw-text-opacity));
#   flex: 0 0 auto;
#   font-size: 1rem;
#   line-height: 1.7;
#   z-index: 2;
# }
#
# .index_rdc-news-card__meta__TNbSg .index_rdc-spacer__E4DSH {
#     display: inline-block;
#     width: 0.5rem;
#   }
# </style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-news-card__baleq {
#   position: relative;
#   display: flex;
#   cursor: pointer;
#   flex-direction: column;
#   align-items: stretch;
#   height: 100%;
#   width: 100%;
#   --tw-bg-opacity: 1;
#   background-color: rgba(255, 255, 255, var(--tw-bg-opacity));
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-news-card__baleq:hover {
#     --tw-shadow: 0 4px 6px -1px rgba(0, 0, 0, 0.1), 0 2px 4px -1px rgba(0, 0, 0, 0.06);
#     box-shadow: var(--tw-ring-offset-shadow, 0 0 #0000), var(--tw-ring-shadow, 0 0 #0000), var(--tw-shadow);
#   }
# }
#
# .index_rdc-news-card__baleq {
#   transition-property: box-shadow;
#   transition-timing-function: cubic-bezier(0.4, 0, 0.2, 1);
#   transition-duration: 150ms;
#   transition-duration: 200ms;
#   transition-timing-function: cubic-bezier(0, 0, 0.2, 1);
# }
#
# .index_rdc-news-card--hero__5hD-E, .index_rdc-news-card--featured__PhB5k, .index_rdc-news-card--mini__m14Un {
#   background-color: transparent;
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-news-card--hero__5hD-E, .index_rdc-news-card--featured__PhB5k, .index_rdc-news-card--mini__m14Un {
#     --tw-bg-opacity: 1;
#     background-color: rgba(255, 255, 255, var(--tw-bg-opacity));
#   }
# }
#
# .index_rdc-news-card--mini__m14Un {
#   flex-direction: row;
#   align-items: flex-start
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-news-card--mini__m14Un:hover {
#     --tw-shadow: 0 0 #0000;
#     box-shadow: var(--tw-ring-offset-shadow, 0 0 #0000), var(--tw-ring-shadow, 0 0 #0000), var(--tw-shadow);
#   }
# }
#
# .index_rdc-news-card--mini__m14Un .index_rdc-news-card__link__kYr76 {
#     line-height: 1.3rem;
#     font-weight: 400;
#     font-size: 1.1rem ;
#   }
#
# .index_rdc-news-card--mini__m14Un .index_rdc-news-card__detail__ErB1W {
#     border: none;
#     display: flex;
#     justify-content: space-between;
#     align-self: stretch;
#   }
#
# .index_rdc-news-card--inline__bef0i {
#   float: right;
#   width: 32%;
# }
#
# @media (min-width: 1024px) {
#
# .index_rdc-news-card--inline__bef0i {
#     margin-left: 1.7em
# }
#   }
#
# .index_rdc-news-card--inline__bef0i .index_rdc-news-card--featured__PhB5k .index_rdc-news-card__title__Ypfs- {
#       font-weight: 700;
#       font-size: 1.4rem ;
#     }
#
# .index_rdc-news-card__detail__ErB1W {
#   border: 1px solid #DEDEDE;
# }
#
# .index_rdc-news-list__heading__mrWTO {
#   font-family: Circular, Helvetica Neue, Helvetica, Arial, sans-serif;
#   font-weight: 900;
#   --tw-text-opacity: 1;
#   color: rgba(51, 51, 51, var(--tw-text-opacity));
#   border-bottom-width: 2px;
#   font-size: 1.4rem;
#   line-height: 1.4;
#   padding: 0 1.2rem 0.8rem;
# }
#
# .index_rdc-news-list__heading--inline__ui66g {
#   --tw-bg-opacity: 1;
#   padding: 0.5625em 1rem;
#   border-color: black;
#   display: flex;
#   align-items: center;
#   justify-content: space-between;
#   font-family: Circular, Helvetica Neue, Helvetica, Arial, sans-serif;
#   line-height: 1;
#   --tw-text-opacity: 1;
#   font-size: 1.4rem;
#   letter-spacing: -0.02px;
#   margin-bottom: 	0.75rem;
# }
#
# .index_rdc-news-card__thumbnail__ohe0t {
#   flex: 0 0 auto;
#   transition-property: opacity;
#   transition-timing-function: cubic-bezier(0.4, 0, 0.2, 1);
#   transition-duration: 150ms;
# }
#
# .index_rdc-news-card__baleq:hover .index_rdc-news-card__thumbnail__ohe0t {
#     opacity: 0.8;
#   }
#
# .index_rdc-news-card--placeholder__td7m5 .index_rdc-news-card__thumbnail__ohe0t::before {
#     display: block;
#     --tw-bg-opacity: 1;
#     background-color: rgba(222, 222, 222, var(--tw-bg-opacity));
#     content: '';
#     padding-bottom: 56.25%;
#   }
#
# .index_rdc-news-card--mini__m14Un .index_rdc-news-card__thumbnail__ohe0t {
#     margin-right: 1rem;
#     width: 12rem;
#   }
#
# .index_rdc-news-card__detail__ErB1W {
#   display: flex;
#   flex-grow: 1;
#   flex-direction: column;
#   padding: 1.25rem;
# }
#
# .index_rdc-news-card--bordered__Iq5fk .index_rdc-news-card__detail__ErB1W {
#     border: 1px solid #DEDEDE
#   }
#
# .index_rdc-news-card--mini__m14Un .index_rdc-news-card__detail__ErB1W {
#     padding: 0px;
#     font-weight: 400;
#   }
#
# .index_rdc-news-card--placeholder__td7m5 .index_rdc-news-card__detail__ErB1W {
#     --tw-bg-opacity: 1;
#     background-color: rgba(245, 245, 245, var(--tw-bg-opacity));
#   }
#
# .index_rdc-news-card__link__kYr76 {
#   z-index: 1;
# }
#
# .index_rdc-news-card__link__kYr76:after {
#     content: '';
#     left: 0;
#     top: 0;
#     width: 100%;
#     height: 100%;
#     position: absolute;
#     display: block;
#     cursor: pointer;
#   }
#
# .index_rdc-news-card__title__Ypfs- {
#   font-family: Circular, Helvetica Neue, Helvetica, Arial, sans-serif;
#   font-weight: 700;
#   --tw-text-opacity: 1;
#   color: rgba(51, 51, 51, var(--tw-text-opacity));
#   transition-property: background-color, border-color, color, fill, stroke;
#   transition-timing-function: cubic-bezier(0.4, 0, 0.2, 1);
#   transition-duration: 150ms;
#   transition-duration: 300ms;
#   transition-timing-function: cubic-bezier(0, 0, 0.2, 1);
#   flex: 0 0 auto;
#   margin-bottom: 0.8rem;
#   font-size: 1.4rem;
#   line-height: 1.2;
# }
#
# @media (min-width: 1024px) {
#
# .index_rdc-news-card__title__Ypfs- {
#     height: 2.4em;
#
#     margin-bottom: 1.2rem
# }
#   }
#
# .index_rdc-news-card--featured__PhB5k .index_rdc-news-card__title__Ypfs- {
#     height: auto;
#   }
#
# @media (min-width: 1024px) {
#
# .index_rdc-news-card--featured__PhB5k .index_rdc-news-card__title__Ypfs- {
#       font-size: 2rem
#   }
#     }
#
# @media (min-width: 1024px) {
#
# .index_rdc-news-card--hero__5hD-E .index_rdc-news-card__title__Ypfs- {
#       font-size: 3rem
#   }
#     }
#
# .index_rdc-news-card--mini__m14Un .index_rdc-news-card__title__Ypfs- {
#     font-weight: 400;
#     font-size: 1.1rem;
#   }
#
# .index_rdc-news-card__baleq:hover .index_rdc-news-card__title__Ypfs- {
#     --tw-text-opacity: 1;
#     color: rgba(237, 28, 36, var(--tw-text-opacity));
#   }
#
# .index_rdc-news-card__description__v-RnZ {
#   flex-grow: 1;
#   font-weight: 400;
#   --tw-text-opacity: 1;
#   color: rgba(51, 51, 51, var(--tw-text-opacity));
#   font-size: 1.1rem;
#   line-height: 1.4;
#   margin-bottom: 1.2rem;
# }
#
# @media (min-width: 1024px) {
#
# .index_rdc-news-card__description__v-RnZ {
#     font-size: 1.4rem
# }
#   }
#
# .index_rdc-news-card__meta__TNbSg {
#   pointer-events: none;
#   font-family: Roboto, Helvetica Neue, Helvetica, Arial, sans-serif;
#   font-weight: 400;
#   --tw-text-opacity: 1;
#   color: rgba(153, 153, 153, var(--tw-text-opacity));
#   flex: 0 0 auto;
#   font-size: 1rem;
#   line-height: 1.7;
#   z-index: 2;
# }
#
# .index_rdc-news-card__meta__TNbSg .index_rdc-spacer__E4DSH {
#     display: inline-block;
#     width: 0.5rem;
#   }
# </style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-news-grid__BG4zm {
#   display: grid;
#   grid-template-columns: repeat(1, minmax(0, 1fr));
#   gap: 2rem;
# }
#
# @media (min-width: 768px) {
#   .index_rdc-news-grid__BG4zm {
#     grid-template-columns: repeat(2, minmax(0, 1fr));
#   }
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-news-grid__BG4zm {
#     grid-template-columns: repeat(4, minmax(0, 1fr));
#   }
# }
#
# .index_rdc-news-grid__BG4zm {
#   padding-left: 0px;
#   padding-right: 0px;
# }
#
# .index_rdc-news-grid__item__uveAG:focus-within {
#   outline: 2px solid transparent;
#   outline-offset: 2px;
# }
# </style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-section-heading__5wTjc {
#   display: flex;
#   align-items: center;
#   justify-content: space-between;
#   --tw-bg-opacity: 1;
#   background-color: rgba(51, 51, 51, var(--tw-bg-opacity));
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-section-heading__5wTjc {
#     display: inline-flex;
#   }
# }
#
# .index_rdc-section-heading__5wTjc {
#   font-family: Circular, Helvetica Neue, Helvetica, Arial, sans-serif;
#   font-weight: 700;
#   line-height: 1;
#   --tw-text-opacity: 1;
#   color: rgba(255, 255, 255, var(--tw-text-opacity));
#   padding: 0.8rem 1rem;
#   font-size: 1.4rem;
#   letter-spacing: -0.02px;
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-section-heading--sidebar__ZvW3i {
#     display: flex;
#   }
# }
#
# .index_rdc-section-heading--sidebar__ZvW3i {
#   padding: 1.3rem 1rem;
# }
#
# .index_rdc-section-heading__more__w2A3q {
#   font-family: Roboto, Helvetica Neue, Helvetica, Arial, sans-serif;
#   font-weight: 400
# }
#
# @media (min-width: 1024px) {
#   .index_rdc-section-heading__more__w2A3q {
#     display: none;
#   }
# }
#
# .index_rdc-section-heading__more__w2A3q {
#   font-size: 1.2rem;
# }
#
# .index_rdc-section-heading__more__w2A3q .index_rdc-spacer__aqHY8 {
#     display: inline-block;
#     width: 0.5rem;
#   }
# </style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-horizontal-divider__4azSb {
#   --tw-border-opacity: 1;
#   border-color: rgba(222, 222, 222, var(--tw-border-opacity));
#   margin-top: 0.5rem;
#   margin-bottom: 0.5rem;
#   border-bottom-width: 1px;
#   width: 100%;
# }
# </style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-table-row__XoMhX {
# }
#
# .index_rdc-table-row--clickable__OT9ec {
#   cursor:pointer;
# }
#
# .index_rdc-table-row--clickable__OT9ec:hover{
#     background-color: #f5f5f5;
#   }
#
# .index_rdc-race-entry__15llV {
#   display: grid;
#   align-items: center;
#   justify-content: center;
#   padding-top: 15px;
#   padding-right: 5px;
#   padding-bottom: 15px;
# }
#
# .index_rdc-race-entry__scratched__xVdKS {
#   opacity: 0.4;
# }</style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-table-cell__XouUW {
#   display: flex;
# }
#
# .index_rdc-table-cell__center__1nsfz {
#   display: flex;
#   align-items: flex-start;
#   justify-content: center;
# }
#
# .index_rdc-table-cell__between__orD7V {
#   display: flex;
#   align-items: flex-start;
#   justify-content: space-between;
# }
#
# .index_rdc-table-cell__left__-9lyS {
#   display: flex;
#   align-items: flex-start;
#   justify-content: flex-start;
# }
#
# .index_rdc-table-cell__right__CoqES {
#   display: flex;
#   align-items: flex-start;
#   justify-content: flex-end;
# }
# </style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-image__-W-xN {
# }
#
# .index_rdc-image__img__9-wjT {
#   display: block;
#   width: 100%;
# }
#
# .index_rdc-image__img--allow-width__eSH6N{
#   max-width: -moz-fit-content;
#   max-width: fit-content;
#   min-width: 100%;
#   width: auto;
#   position: absolute;
#   right: 0;
# }
#
# .index_rdc-image__caption__q2aSE {
#   --tw-bg-opacity: 1;
#   background-color: rgba(245, 245, 245, var(--tw-bg-opacity));
#   font-size: 1.0rem;
#   --tw-text-opacity: 1;
#   color: rgba(102, 102, 102, var(--tw-text-opacity));
#   padding: 0.9rem;
# }
#
# @media (min-width: 1024px) {
#
# .index_rdc-image__caption__q2aSE {
#     padding: 1.4rem 1.6rem;
#
#     font-size: 1.2rem;
#
#     --tw-text-opacity: 1;
#
#     color: rgba(51, 51, 51, var(--tw-text-opacity));
#
#     --tw-text-opacity: 1;
#
#     color: rgba(153, 153, 153, var(--tw-text-opacity))
# }
#   }
# </style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-horse-detail--silkIcon__C-wLr {
#   width: 3.2rem;
#   margin-right: 10px;
# }</style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-link__aXFTn {
#   cursor: pointer;
#   color: #666;
# }
# .index_rdc-link__aXFTn .index_rdc-link--label__GFZdj {
#     transition: 0.2s all ease;
#     cursor: pointer;
#   }
# .index_rdc-link__aXFTn .index_rdc-link--label__GFZdj:hover {
#     color: inherit !important;
#   }
#
# </style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-horse-detail__atP-G {
#   display: flex;
#   flex-direction: row;
#   list-style: none;
#   align-items: center;
# }
#
# .index_rdc-horse-detail--text__zYPv4 a {
#     transition: 0.2s all ease;
#     cursor: pointer;
#     height: 15px;
#   }
#
# .index_rdc-horse-detail--text__horseLink__zNR1R:hover {
#     --tw-text-opacity: 1;
#     color: rgba(237, 28, 36, var(--tw-text-opacity));
#   }
#
# .index_rdc-horse-detail--text__link__HafuZ:hover {
#     color: #333;
#   }
#
# .index_rdc-horse-detail--silkIcon__39ZIo {
#   width: 3.2rem;
#   margin-right: 10px;
# }</style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-horse-detail--text__03hjb {
#   min-width: 15rem;
# }
# </style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-basic-text__AyDZW {
#   --tw-text-opacity: 1;
#   color: rgba(51, 51, 51, var(--tw-text-opacity));
#   font-size: 1.2rem;
# }
#
# .index_rdc-basic-text--size2__cJkxT {
#   font-size: 2rem;
# }
#
# .index_rdc-basic-text--size3__XWaBs {
#   font-size: 3rem;
# }
#
# .index_rdc-basic-text--size4__zmF9u {
#   font-size: 4rem;
# }
# </style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-table-header__DWfYg {
#   height: 4rem;
#   align-items: center;
#   --tw-bg-opacity: 1;
#   background-color: rgba(241, 241, 241, var(--tw-bg-opacity));
#   align-items: center;
# }</style><style type="text/css">/*! racing-ui v1.0.0 */
# .index_rdc-button__qsTKo {
#   border-width: 1px;
#   --tw-border-opacity: 1;
#   border-color: rgba(153, 153, 153, var(--tw-border-opacity));
#   padding: 1rem;
#   font-family: Circular, Helvetica Neue, Helvetica, Arial, sans-serif;
#   font-size: 1.4rem;
#   font-weight: 700;
#   --tw-text-opacity: 1;
#   color: rgba(153, 153, 153, var(--tw-text-opacity));
#   letter-spacing: -0.02px;
#   line-height: 1;
#   transition: all 0.3s ease-out;
# }
# .index_rdc-button__qsTKo:hover, .index_rdc-button__qsTKo:active {
#     --tw-border-opacity: 1;
#     border-color: rgba(51, 51, 51, var(--tw-border-opacity));
#     --tw-text-opacity: 1;
#     color: rgba(51, 51, 51, var(--tw-text-opacity));
#   }
# .index_rdc-button__qsTKo:focus {
#     --tw-border-opacity: 1;
#     border-color: rgba(51, 51, 51, var(--tw-border-opacity));
#     outline: 2px solid transparent;
#     outline-offset: 2px;
#   }
#
# .index_rdc-button--white-hover__5K7VW:hover, .index_rdc-button--white-hover__5K7VW:active {
#     --tw-border-opacity: 1;
#     border-color: rgba(255, 255, 255, var(--tw-border-opacity));
#     --tw-text-opacity: 1;
#     color: rgba(255, 255, 255, var(--tw-text-opacity));
#   }
#
# .index_rdc-button--white-hover__5K7VW:focus {
#     --tw-border-opacity: 1;
#     border-color: rgba(255, 255, 255, var(--tw-border-opacity));
#     outline: 2px solid transparent;
#     outline-offset: 2px;
#   }
#
# .index_rdc-button--small__b-1wD {
#   text-align: center;
# }
#
# @media (min-width: 1024px) {
#
# .index_rdc-button--small__b-1wD {
#     text-align: left;
#
#     position: relative;
#
#     line-height: 2;
#
#     display: flex;
#
#     align-items: center;
#
#     margin-right: 0.375rem;
#
#     padding-top: 0.25rem;
#
#     padding-bottom: 0.25rem;
#
#     padding-left: 1.25rem;
#
#     padding-right: 1.25rem;
#
#     --tw-text-opacity: 1;
#
#     color: rgba(102, 102, 102, var(--tw-text-opacity));
#
#     font-weight: 700;
#
#     font-size: 1rem
# }
#   }
#
# .index_rdc-button--small__b-1wD .index_rdc-badge__bwV4V {
#     margin-left: 5px;
#   }
#
# .index_rdc-button--small__b-1wD .index_rdc-badge__bwV4V .index_rdc-badge-container--link__QY4Wi:after{
#       content: '';
#       left: 0;
#       top: 0;
#       width: 100%;
#       height: 100%;
#       position: absolute;
#       display: block;
#     }
#
# .index_rdc-button--wide__2A4Nx {
#   width: 100%;
#   max-width: 37rem;
# }
# </style><style data-emotion="css"></style><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><meta http-equiv="origin-trial" content=""><script src="https://securepubads.g.doubleclick.net/pagead/managed/js/gpt/m202401250101/pubads_impl.js?cb=31080709" async=""></script><meta http-equiv="origin-trial" content=""></head>
#   <body><noscript>
#       <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NJJTCC&gtm_auth=&gtm_preview=&gtm_cookies_win=x"
#         height="0" width="0" style="display:none;visibility:hidden" id="tag-manager"></iframe></noscript>
#     <div id="root"><div class="fixed top-0 w-full z-50"><header class="css-1aang0r"><div class="css-cunl67"><div class="index_rdc-container__r5ivn"><div class="header--desktop css-11bslyj"><a class="rdc-logo css-1d060i4" href="https://racing.com/"><svg id="Layer_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" viewBox="0 0 487.7 55.9" width="487" height="56" xml:space="preserve" style="width: 100%; height: 15px;"><g fill="currentColor"><path d="M300.1,39.4c-4.6,0-8.9,3.7-9.8,8.3c-0.9,4.6,2,8.2,6.6,8.2c4.6,0,9-3.6,9.9-8.2C307.7,43.1,304.7,39.4,300.1,39.4z"></path><path d="M344.6,12.8c4.4,0,7.7,0.8,12.7,3l2.4-12.4c-3-2.2-8.4-3.5-14-3.5C325,0,314,13.2,311.2,28c-2.9,14.8,2.9,28,23.7,28c5.6,0,11.5-1.2,15.3-3.4l2.4-12.4c-5.9,2.3-9.5,3-13.9,3c-12.2,0-13.3-7.9-11.9-15.2C328.2,20.7,332.3,12.8,344.6,12.8z"></path><path d="M391.9,0C373.4,0,362,12.5,359,27.8c-3,15.4,3.5,28.1,22,28.1c18.3,0,29.9-12.7,32.9-28.1C416.8,12.5,410.2,0,391.9,0z M398.3,27.8c-1.9,9.7-7.3,16-14.9,16c-7.6,0-10.7-6.3-8.8-16c1.9-9.6,7.3-15.7,14.9-15.7C397.2,12.1,400.1,18.2,398.3,27.8z"></path><path d="M469.8,1.1l-15.5,21.7c-1.3,1.8-2.4,3.6-3.4,5.5c-0.3-1.8-0.7-3.7-1.3-5.5l-7.3-21.7h-17.9l-10.3,54.2h14l3.9-20.7c0.7-3.8,1.3-8.7,1.8-14l3.1,10.5c4,13.5,3.9,17.1,3.9,21.1h11c1.5-4,1.8-7.8,11.2-21.1l8.1-11.3c-1.7,5.7-3.1,10.9-3.8,14.9l-4,20.7h14.1l10.3-54.2H469.8z"></path><path d="M80.1,1.1C66.5,15.6,56.6,33.1,53.7,48.1l-1.4,7.1h15.2l1.4-7.1c0.3-1.3,0.5-2.8,1-4.2h19c-0.2,1.4-0.4,2.8-0.7,4.2l-1.4,7.1h15.2l1.4-7.1c2.9-15-0.2-32.6-8.2-47.1H80.1z M73.8,32.6c2.9-6.4,6.7-12.8,11.3-19h0.3c2.3,6.2,3.6,12.5,3.9,19H73.8z"></path><path d="M31.3,0c-7.4,0-12.2,0.6-21.3,3.4L0,55.2h14.9l3.6-18.7c1.5,0.1,2.9,0.3,4.5,0.3l2.3,5.3c4.9,11.4,10.9,15.4,22.2,13.1l2.3-12c-5.1,0.5-7.3-1.6-10.4-8.4L38.6,33c6.9-2.8,11.6-7.8,12.9-14.4C53.3,9.2,48,0,31.3,0zM36.1,18.6c-1,5.1-5.1,7.3-10.1,7.3c-1.8,0-3.7-0.1-5.4-0.4l2.5-13c1.8-0.3,3.6-0.4,5.8-0.4C35.2,12.1,36.7,15.2,36.1,18.6z"></path><path d="M225.1,1.1l-3,15.2c-0.6,3-1,6.9-1.4,11c-0.5-1.3-1.2-2.5-1.9-3.6L203.1,1.1h-12.9l-10.5,54.2h14.2l3.9-20.3c0.6-3.2,1.2-7.4,1.6-12l13.7,20c2.2,3.4,3.9,7.4,4.9,12.3h10.8l10.5-54.2H225.1z"></path><path d="M143.4,12.8c4.4,0,7.7,0.8,12.7,3l2.4-12.4c-3-2.2-8.4-3.5-14-3.5c-20.7,0-31.7,13.2-34.5,28c-2.9,14.8,2.9,28,23.7,28c5.6,0,11.5-1.2,15.3-3.4l2.4-12.4c-5.9,2.3-9.5,3-13.9,3c-12.2,0-13.3-7.9-11.9-15.2C127,20.7,131.2,12.8,143.4,12.8z"></path><path d="M274.3,12.8c6.6,0,9.9,0.8,14.9,3l2.4-12.4c-3-2.2-9-3.5-14.8-3.5c-22.7,0-34.3,13.1-37.3,28.5c-2.9,14.8,2.2,27.4,25,27.4c4.4,0,14-1.3,19.3-3.5l4.4-22.9h-14.5l-2.7,14.1c-1.3,0.1-2.7,0.2-4,0.2c-12.2,0-13.3-8.1-11.9-15.3C256.8,19.3,262.4,12.8,274.3,12.8z"></path><polygon points="166.7,1.1 156.2,55.2 171.4,55.2 181.9,1.1"></polygon></g></svg></a><div class="header__padding css-1qe1pxe"><div class="css-4cffwv"><div class="css-54l5zj"><div class="css-1gcvvz2"><div class="css-1ilfwwu">Racing</div><div class="css-ylfv1q"></div><div class="css-1y61jow"><div class="rdc-header__menu-col rdc-header__menu-col--plain css-esl7ex"><div class="css-1jll2aj"><div class="css-4v50qp"><div class="css-hny6m2"><a href="https://www.racing.com/todays-racing" target="" class="css-1b9hzrf">Today's Racing</a><a href="https://www.racing.com/todays-racing#/results" target="" class="css-1b9hzrf">Latest Results</a><a href="https://www.racing.com/tips" target="" class="css-1b9hzrf">Today's Tips</a><a href="https://www.racing.com/calendar" target="" class="css-1b9hzrf">Racing Calendar</a><a href="https://www.racing.com/group-races-calendar" target="" class="css-1b9hzrf">Group Races Calendar</a></div></div></div></div><div class="rdc-header__menu-col rdc-header__menu-col--contained css-mwatd9"><div class="css-1jll2aj"><h3 class="css-z7m1yq">Profiles &amp; Stats</h3><div class="css-4v50qp"><div class="css-hny6m2"><a href="https://www.racing.com/horses" target="" class="css-1b9hzrf">Horse Profiles</a><a href="https://www.racing.com/jockeys" target="" class="css-1b9hzrf">Jo ...
#
#
#
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-D09593FEJ7"></script><div class=""></div><div style="display: none; visibility: hidden;">
# <script>!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","//connect.facebook.net/en_US/fbevents.js");fbq("init","1631310827106969");fbq("track","PageView");</script>
# <noscript></noscript>
# </div><script type="text/javascript" id="">(function(a,e,b,f,g,c,d){a[b]=a[b]||function(){(a[b].q=a[b].q||[]).push(arguments)};c=e.createElement(f);c.async=1;c.src="https://www.clarity.ms/tag/"+g+"?ref\x3dgtm2";d=e.getElementsByTagName(f)[0];d.parentNode.insertBefore(c,d)})(window,document,"clarity","script","kp9uulpfgi");</script><iframe src="https://737b2c8de422b79b918908f67a8c32c1.safeframe.googlesyndication.com/safeframe/1-0-40/html/container.html" style="visibility: hidden; display: none;"></iframe><iframe src="https://www.google.com/recaptcha/api2/aframe" width="0" height="0" style="display: none;"></iframe></body></html> html.parser

# %%
# You may need to wait for the page to load
#flex w-full pt-14 
#w-full pl-2
elements = driver.find_elements(By.CLASS_NAME, 'flex w-full pt-14') 
#trainers_names = [element.text for element in trainers_elements]
elements
# Out:
# []

# %%
 from selenium.webdriver.common.by import By
 #driver.find_element(By.CLASS_NAME,'w-full pl-2')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [34], in <cell line: 2>()
#       1 from selenium.webdriver.common.by import By
# ----> 2 driver.find_element(By.CLASS_NAME,'w-full pl-2')
#
# File c:\Users\IM_py\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:976, in WebDriver.find_element(self, by, value)
#     974         by = By.CSS_SELECTOR
#     975         value = '[name="%s"]' % value
# --> 976 return self.execute(Command.FIND_ELEMENT, {
#     977     'using': by,
#     978     'value': value})['value']
#
# File c:\Users\IM_py\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
#     320 if response:
# --> 321     self.error_handler.check_response(response)
#     322     response['value'] = self._unwrap_value(
#     323         response.get('value', None))
#     324     return response
#
# File c:\Users\IM_py\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:242, in ErrorHandler.check_response(self, response)
#     240         alert_text = value['alert'].get('text')
#     241     raise exception_class(message, screen, stacktrace, alert_text)
# --> 242 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".w-full pl-2"}
#   (Session info: chrome=120.0.6099.225)

# %%
#for name in trainers_names:
#    print(name)

#driver.quit()
