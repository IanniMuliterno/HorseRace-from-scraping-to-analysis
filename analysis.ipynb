# %%
#import modules
import os
import glob
import pandas as pd
#list all csv files only
csv_files = glob.glob('previous*.{}'.format('csv'))
csv_files
# Out:
# ['previous_races_aaron-bidlake-nz.csv',
#  'previous_races_adrian-bull-nz.csv',
#  'previous_races_alby-macgregor-nz.csv',
#  'previous_races_allan-sharrock-nz.csv',
#  'previous_races_andrew-forsman-nz.csv',
#  'previous_races_bill-thurlow-nz.csv',
#  'previous_races_chad-ormsby-nz.csv',
#  'previous_races_chris-gibbs-nz.csv',
#  'previous_races_chris-wood-nz.csv',
#  'previous_races_craig-ivil-nz.csv',
#  'previous_races_danica-guy-nz.csv',
#  'previous_races_david-greene-nz.csv',
#  'previous_races_david-haworth-nz.csv',
#  'previous_races_frank-ritchie-nz.csv',
#  'previous_races_fraser-auret-nz.csv',
#  'previous_races_gary-vile-nz.csv',
#  'previous_races_guy-lowry-nz.csv',
#  'previous_races_james-bridge-nz.csv',
#  'previous_races_jeff-lynds-nz.csv',
#  'previous_races_jim-pender-nz.csv',
#  'previous_races_john-bary-nz.csv',
#  'previous_races_john-morell-nz.csv',
#  'previous_races_john-wheeler-nz.csv',
#  'previous_races_karen-fursdon-nz.csv',
# ...

# %%
df_append = pd.DataFrame()
#append all files together
for file in csv_files:
            df_temp = pd.read_csv(file)
            df_append = df_append.append(df_temp, ignore_index=True)
df_append
# Out:
# C:\Users\IM_py\AppData\Local\Temp\ipykernel_31496\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\IM_py\AppData\Local\Temp\ipykernel_31496\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\IM_py\AppData\Local\Temp\ipykernel_31496\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# C:\Users\IM_py\AppData\Local\Temp\ipykernel_31496\3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df_append[df_append['Horse'].str.contains('Richter')]
# Out:
# Empty DataFrame
# Columns: [Position, Horse, Trainer, Jockey, Track, Date, Distance, Condition, Prize, Class, WGT, Pos_800_400, Margin, Rating, Odds]
# Index: []

# %%
df_append[df_append['Trainer'].str.contains('Pickford')]
# Out:
# Empty DataFrame
# Columns: [Position, Horse, Trainer, Jockey, Track, Date, Distance, Condition, Prize, Class, WGT, Pos_800_400, Margin, Rating, Odds]
# Index: []

# %%
df_append[df_append['Jockey'].str.contains('Hemi')]
# Out:
#    Position        Horse              Trainer    Jockey    Track       Date  \
# 14      4-9  Benzini (5)  Adrian & Harry Bull  L.T.Hemi  TREN R8  09 DEC 17
#
#    Distance Condition    Prize            Class   WGT Pos_800_400 Margin  \
# 14    1600M      Good  $192.7K  G1 CAPTAIN COOK  59kg           -     2L
#
#    Rating Odds
# 14      -  $26
